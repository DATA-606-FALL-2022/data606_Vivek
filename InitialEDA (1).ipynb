# %% [markdown]
# # BUSINESS ANAYLSIS AND FUTURE BUSINESS PREDICTION

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ## Importing Packages:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Data:

# %%
df=pd.read_csv("5krecords.csv")

# %%
df.head(20)
# Out:
#                                Region                         Country  \
# 0                              Europe                         Germany
# 1                                Asia                      Kazakhstan
# 2               Australia and Oceania                Marshall Islands
# 3                                Asia                     South Korea
# 4        Middle East and North Africa                           Yemen
# 5   Central America and the Caribbean                       Nicaragua
# 6                  Sub-Saharan Africa                     Seychelles
# 7        Middle East and North Africa                           Qatar
# 8                                Asia                       Indonesia
# 9                  Sub-Saharan Africa                     South Sudan
# 10                 Sub-Saharan Africa                     South Sudan
# 11                 Sub-Saharan Africa                    Sierra Leone
# 12                      North America        United States of America
# 13              Australia and Oceania  Federated States of Micronesia
# 14                             Europe                         Armenia
# 15                 Sub-Saharan Africa                         Namibia
# 16                             Europe                         Romania
# 17                 Sub-Saharan Africa                      Cape Verde
# 18                 Sub-Saharan Africa                         Namibia
# 19       Middle East and North Africa                         Somalia
#
#           Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0            Fruits        Online              H   4/22/2019  100470674
# 1         Baby Food        Online              C   6/11/2015  101197659
# 2         Cosmetics       Offline              H  11/25/2019  101942241
# 3         Household        Online              L   5/22/2015  102101457
# 4              Meat        Online              L    1/3/2016  102274835
# 5           Clothes        Online              L   2/21/2019  103064048
# 6     Personal Care        Online              M   12/5/2017  103465735
# 7         Cosmetics        Online              M   4/15/2019  103579461
# 8         Cosmetics       Offline              C   9/21/2017  103972136
# 9   Office Supplies       Offline              C   3/14/2019  104088866
# 10          Clothes       Offline              H   4/24/2019  104327905
# 11        Cosmetics       Offline              L   3/17/2017  104509866
# 12        Cosmetics        Online              C    3/2/2017  104587543
# 13           Snacks        Online              H   7/29/2019  104846322
# 14          Clothes        Online              M  10/13/2017  104996955
# 15        Cosmetics        Online              M   6/30/2016  105081927
# 16        Beverages       Offline              L    9/6/2019  105321395
# 17       Vegetables        Online              L   9/10/2017  105624377
# 18           Snacks       Offline              M   6/27/2020  105814492
# 19        Household        Online              H  12/16/2017  105906760
#
#      Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0    4/24/2019         360        9.33       6.92        3358.80     2491.20
# 1    6/25/2015        5491      255.28     159.42     1401742.48   875375.22
# 2   11/26/2019        5829      437.20     263.33     2548438.80  1534950.57
# 3     6/8/2015        2945      668.27     502.54     1968055.15  1479980.30
# 4    2/13/2016        4251      421.89     364.69     1793454.39  1550297.19
# 5    3/27/2019        7797      109.28      35.84      852056.16   279444.48
# 6     1/8/2018        6665       81.73      56.67      544730.45   377705.55
# 7    4/17/2019         319      437.20     263.33      139466.80    84002.27
64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 549.0+ KB

# %% [markdown]
# ## Finding missing values and dropping:

# %%
print("Missing Values :",df.isnull().any())
# Out:
# Missing Values : Region            False
# Country           False
# Item Type         False
# Sales Channel     False
# Order Priority    False
# Order Date        False
# Order ID          False
# Ship Date         False
# Units Sold        False
# Unit Price        False
# Unit Cost         False
# Total Revenue     False
# Total Cost        False
# Total Profit      False
# dtype: bool

# %%
print("Unique Values : ",df.nunique())
# Out:
# Unique Values :  Region               7
# Country            152
# Item Type           12
# Sales Channel        2
# Order Priority       4
# Order Date        1853
# Order ID          4674
# Ship Date         1883
# Units Sold        3646
# Unit Price          12
# Unit Cost           12
# Total Revenue     4525
# Total Cost        4524
# Total Profit      4525
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
missing_values = df.isna().sum()
print('Column Names                   Missing Values')
missing_values[missing_values>0]
# Out:
# Column Names                   Missing Values
# Series([], dtype: int64)

# %% [markdown]
# This means it has 0 missing values.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.hist(figsize=(12,12))
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), cmap="gist_stern_r")
plt.show()

# %% [markdown]
# ## Comparing using "Region" column

# %%
sns.pairplot(df,hue='Region',)

# %% [markdown]
# ## Featuring the columns:

# %%
print("Features : ",df.columns.tolist())
# Out:
# Features :  ['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority', 'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']

# %%
df.rename(columns={'Order Date':'orderDate','Item Type':'itemtype','Total Profit':'total_profit'},inplace=True)
df=df[['orderDate','itemtype','total_profit']] 
   

df['orderDate']=pd.to_datetime(df['orderDate'],infer_datetime_format=True)
# Out:
# <ipython-input-133-e1fefab320a7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['orderDate']=pd.to_datetime(df['orderDate'],infer_datetime_format=True)

# %%
df['orderDate'] = df['orderDate'].map(lambda x: x.strftime('%Y-%m'))  #converting to year and month
item_df=df.set_index('orderDate')
# Out:
# <ipython-input-134-b1cb332fbab1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['orderDate'] = df['orderDate'].map(lambda x: x.strftime('%Y-%m'))  #converting to year and month

# %%
df.head(22)
# Out:
#    orderDate         itemtype  total_profit
# 0    2019-04           Fruits        867.60
# 1    2015-06        Baby Food     526367.26
# 2    2019-11        Cosmetics    1013488.23
# 3    2015-05        Household     488074.85
# 4    2016-01             Meat     243157.20
# 5    2019-02          Clothes     572611.68
# 6    2017-12    Personal Care     167024.90
# 7    2019-04        Cosmetics      55464.53
# 8    2017-09        Cosmetics    1133806.27
# 9    2019-03  Office Supplies     134203.75
# 10   2019-04          Clothes     132192.00
# 11   2017-03        Cosmetics     981843.89
# 12   2017-03        Cosmetics    1501019.71
# 13   2019-07           Snacks     287334.54
# 14   2017-10          Clothes     718757.28
# 15   2016-06        Cosmetics     857526.84
# 16   2019-09        Beverages      90765.36
# 17   2017-09       Vegetables     344374.15
# 18   2020-06           Snacks      94565.10
# 19   2017-12        Household    1494718.87
# 20   2018-03       Vegetables     361166.73
# 21   2016-09  Office Supplies     770377.50
